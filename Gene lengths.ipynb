# %%
import urllib.request
import pandas as pd

# %%
source_url = "ftp://ftp.ncbi.nlm.nih.gov/genomes/refseq/bacteria/Escherichia_coli/reference/GCF_000005845.2_ASM584v2/GCF_000005845.2_ASM584v2_genomic.gff.gz"

# %%
gff_file = "E_coli.gff.gz"

# %%
urllib.request.urlretrieve(source_url, gff_file)
# Out:
# ('E_coli.gff.gz', <email.message.Message at 0x18c631073d0>)

# %%
gff_data = pd.read_csv(gff_file, sep="\t", comment="#", names=["seqid", "source", "type", "start", "end", "score", "strand", "phase", "attributes"]
 )

# %%
gff_data
# Out:
#             seqid  source    type    start      end score strand phase  \
# 0     NC_000913.3  RefSeq  region        1  4641652     .      +     .
# 1     NC_000913.3  RefSeq    gene      190      255     .      +     .
# 2     NC_000913.3  RefSeq     CDS      190      255     .      +     0
# 3     NC_000913.3  RefSeq    gene      337     2799     .      +     .
# 4     NC_000913.3  RefSeq     CDS      337     2799     .      +     0
# ...           ...     ...     ...      ...      ...   ...    ...   ...
# 9421  NC_000913.3  RefSeq     CDS  4639590  4640306     .      -     0
# 9422  NC_000913.3  RefSeq    gene  4640402  4640542     .      +     .
# 9423  NC_000913.3  RefSeq     CDS  4640402  4640542     .      +     0
# 9424  NC_000913.3  RefSeq    gene  4640942  4641628     .      +     .
# 9425  NC_000913.3  RefSeq     CDS  4640942  4641628     .      +     0
#
#                                              attributes
# 0     ID=NC_000913.3:1..4641652;Dbxref=taxon:511145;...
# 1     ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...
# 2     ID=cds-NP_414542.1;Parent=gene-b0001;Dbxref=Un...
# 3     ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...
# 4     ID=cds-NP_414543.1;Parent=gene-b0002;Dbxref=Un...
# ...                                                 ...
# 9421  ID=cds-NP_418818.1;Parent=gene-b4401;Dbxref=Un...
# 9422  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...
# 9423  ID=cds-NP_418819.1;Parent=gene-b4402;Dbxref=Un...
# 9424  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...
# 9425  ID=cds-NP_418820.1;Parent=gene-b4403;Dbxref=Un...
#
# [9426 rows x 9 columns]

# %%
gff_data["type"].unique()
# Out:
# array(['region', 'gene', 'CDS', 'mobile_genetic_element', 'ncRNA', 'exon',
#        'rRNA', 'tRNA', 'pseudogene', 'sequence_feature',
#        'origin_of_replication'], dtype=object)

# %%
gff_data["type"].value_counts()
# Out:
# gene                      4464
# CDS                       4324
# exon                       187
# pseudogene                 164
# tRNA                        86
# ncRNA                       79
# mobile_genetic_element      50
# sequence_feature            48
# rRNA                        22
# origin_of_replication        1
# region                       1
# Name: type, dtype: int64

# %%
gff_data["length"] = gff_data["end"] - gff_data["start"] + 1

# %%
gff_data
# Out:
#             seqid  source    type    start      end score strand phase  \
# 0     NC_000913.3  RefSeq  region        1  4641652     .      +     .
# 1     NC_000913.3  RefSeq    gene      190      255     .      +     .
# 2     NC_000913.3  RefSeq     CDS      190      255     .      +     0
# 3     NC_000913.3  RefSeq    gene      337     2799     .      +     .
# 4     NC_000913.3  RefSeq     CDS      337     2799     .      +     0
# ...           ...     ...     ...      ...      ...   ...    ...   ...
# 9421  NC_000913.3  RefSeq     CDS  4639590  4640306     .      -     0
# 9422  NC_000913.3  RefSeq    gene  4640402  4640542     .      +     .
# 9423  NC_000913.3  RefSeq     CDS  4640402  4640542     .      +     0
# 9424  NC_000913.3  RefSeq    gene  4640942  4641628     .      +     .
# 9425  NC_000913.3  RefSeq     CDS  4640942  4641628     .      +     0
#
#                                              attributes   length
# 0     ID=NC_000913.3:1..4641652;Dbxref=taxon:511145;...  4641652
# 1     ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...       66
# 2     ID=cds-NP_414542.1;Parent=gene-b0001;Dbxref=Un...       66
# 3     ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...     2463
# 4     ID=cds-NP_414543.1;Parent=gene-b0002;Dbxref=Un...     2463
# ...                                                 ...      ...
# 9421  ID=cds-NP_418818.1;Parent=gene-b4401;Dbxref=Un...      717
# 9422  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...      141
# 9423  ID=cds-NP_418819.1;Parent=gene-b4402;Dbxref=Un...      141
# 9424  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...      687
# 9425  ID=cds-NP_418820.1;Parent=gene-b4403;Dbxref=Un...      687
#
# [9426 rows x 10 columns]

# %%
#exercise - histogram with gene lenghts of type gene

result = gff_data [gff_data["type"] == "gene"]

# %%
result
# Out:
#             seqid  source  type    start      end score strand phase  \
# 1     NC_000913.3  RefSeq  gene      190      255     .      +     .
# 3     NC_000913.3  RefSeq  gene      337     2799     .      +     .
# 5     NC_000913.3  RefSeq  gene     2801     3733     .      +     .
# 7     NC_000913.3  RefSeq  gene     3734     5020     .      +     .
# 9     NC_000913.3  RefSeq  gene     5234     5530     .      +     .
# ...           ...     ...   ...      ...      ...   ...    ...   ...
# 9416  NC_000913.3  RefSeq  gene  4636696  4638120     .      +     .
# 9418  NC_000913.3  RefSeq  gene  4638178  4639530     .      +     .
# 9420  NC_000913.3  RefSeq  gene  4639590  4640306     .      -     .
# 9422  NC_000913.3  RefSeq  gene  4640402  4640542     .      +     .
# 9424  NC_000913.3  RefSeq  gene  4640942  4641628     .      +     .
#
#                                              attributes  length
# 1     ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...      66
# 3     ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...    2463
# 5     ID=gene-b0003;Dbxref=ASAP:ABE-0000010,ECOCYC:E...     933
# 7     ID=gene-b0004;Dbxref=ASAP:ABE-0000012,ECOCYC:E...    1287
# 9     ID=gene-b0005;Dbxref=ASAP:ABE-0000015,ECOCYC:G...     297
# ...                                                 ...     ...
# 9416  ID=gene-b4399;Dbxref=ASAP:ABE-0014430,ECOCYC:E...    1425
# 9418  ID=gene-b4400;Dbxref=ASAP:ABE-0014432,ECOCYC:E...    1353
# 9420  ID=gene-b4401;Dbxref=ASAP:ABE-0014434,ECOCYC:E...     717
# 9422  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...     141
# 9424  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...     687
#
# [4464 rows x 10 columns]

# %%
result["length"].hist(bins=15, color="red")
# Out:
# <AxesSubplot:>

# %%
def calculate():
    print("calculated value")

# %%
calculate()
# Out:
# calculated value

# %%
def calculate(x):
    res = x + 2
    print(res)

# %%
calculate(2)
# Out:
# 4

# %%
def calculate(row):
    if row["type"] == "gene":
        row["length"] = row["end"] - row["start"] -1
        return row["length"]
    else:
        row["length"] = "no value"
        return row["length"]

# %%
gff_data.apply(calculate, axis=1)
# Out:
# 0       no value
# 1             64
# 2       no value
# 3           2461
# 4       no value
#           ...
# 9421    no value
# 9422         139
# 9423    no value
# 9424         685
# 9425    no value
# Length: 9426, dtype: object

# %%
gff_data["length"] = gff_data.apply(calculate, axis=1)

# %%
gff_data
# Out:
#             seqid  source    type    start      end score strand phase  \
# 0     NC_000913.3  RefSeq  region        1  4641652     .      +     .
# 1     NC_000913.3  RefSeq    gene      190      255     .      +     .
# 2     NC_000913.3  RefSeq     CDS      190      255     .      +     0
# 3     NC_000913.3  RefSeq    gene      337     2799     .      +     .
# 4     NC_000913.3  RefSeq     CDS      337     2799     .      +     0
# ...           ...     ...     ...      ...      ...   ...    ...   ...
# 9421  NC_000913.3  RefSeq     CDS  4639590  4640306     .      -     0
# 9422  NC_000913.3  RefSeq    gene  4640402  4640542     .      +     .
# 9423  NC_000913.3  RefSeq     CDS  4640402  4640542     .      +     0
# 9424  NC_000913.3  RefSeq    gene  4640942  4641628     .      +     .
# 9425  NC_000913.3  RefSeq     CDS  4640942  4641628     .      +     0
#
#                                              attributes    length
# 0     ID=NC_000913.3:1..4641652;Dbxref=taxon:511145;...  no value
# 1     ID=gene-b0001;Dbxref=ASAP:ABE-0000006,ECOCYC:E...        64
# 2     ID=cds-NP_414542.1;Parent=gene-b0001;Dbxref=Un...  no value
# 3     ID=gene-b0002;Dbxref=ASAP:ABE-0000008,ECOCYC:E...      2461
# 4     ID=cds-NP_414543.1;Parent=gene-b0002;Dbxref=Un...  no value
# ...                                                 ...       ...
# 9421  ID=cds-NP_418818.1;Parent=gene-b4401;Dbxref=Un...  no value
# 9422  ID=gene-b4402;Dbxref=ASAP:ABE-0014437,ECOCYC:G...       139
# 9423  ID=cds-NP_418819.1;Parent=gene-b4402;Dbxref=Un...  no value
# 9424  ID=gene-b4403;Dbxref=ASAP:ABE-0014442,ECOCYC:E...       685
# 9425  ID=cds-NP_418820.1;Parent=gene-b4403;Dbxref=Un...  no value
#
# [9426 rows x 10 columns]
